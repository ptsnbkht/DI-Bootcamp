# %% [markdown]
# <a href="https://colab.research.google.com/github/ptsnbkht/DI-Bootcamp/blob/main/week3day5dailychallange.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('USdata.csv')

# Convert 'Order Date' to datetime objects
df['Order Date'] = pd.to_datetime(df['Order Date'])

# Extract the year
df['Order Year'] = df['Order Date'].dt.year

# Group by year and sum the sales
sales_per_year = df.groupby('Order Year')['Sales'].sum().reset_index()

# Plot the line chart
plt.figure(figsize=(12, 6))
plt.plot(sales_per_year['Order Year'], sales_per_year['Sales'], marker='o')
plt.title('Sales Per Year')
plt.xlabel('Year')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group by product and sum the sales
product_sales = df.groupby('Product Name')['Sales'].sum().reset_index()

# Get the top 10 products by sales
top_10_products = product_sales.sort_values(by='Sales', ascending=False).head(10)

# Plot the bar chart using Seaborn
plt.figure(figsize=(14, 7))
sns.barplot(x='Sales', y='Product Name', data=top_10_products)
plt.title('Top 10 Products by Sales')
plt.xlabel('Total Sales')
plt.ylabel('Product Name')
plt.show()

# %%
import matplotlib.pyplot as plt
# Create a scatter plot to analyze the relationship between profit and discount
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Discount', y='Profit', data=df)
plt.title('Relationship between Profit and Discount')
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.show()
